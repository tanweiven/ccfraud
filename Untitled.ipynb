# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.34.0-py2.py3-none-any.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 10.7 MB/s eta 0:00:0000:0100:01
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Collecting rich<14,>=10.14.0
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (4.3.0)
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 9.5 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (1.21.5)
# Requirement already satisfied: packaging<25,>=16.8 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (21.3)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (5.3.0)
# Collecting tenacity<9,>=8.1.0
#   Downloading tenacity-8.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: click<9,>=7.0 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (8.0.4)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (6.1)
# Requirement already satisfied: requests<3,>=2.27 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (2.28.1)
# Collecting protobuf<5,>=3.20
#   Downloading protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.2/394.2 kB 10.4 MB/s eta 0:00:00
# Collecting pyarrow>=7.0
#   Downloading pyarrow-16.1.0-cp39-cp39-macosx_10_15_x86_64.whl (28.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.4/28.4 MB 10.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (1.4.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from streamlit) (9.2.0)
# Collecting altair<6,>=4.0
#   Downloading altair-5.3.0-py3-none-any.whl (857 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.8/857.8 kB 11.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jsonschema>=3.0 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (4.16.0)
# Requirement already satisfied: jinja2 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (2.11.3)
# Requirement already satisfied: toolz in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (0.11.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from packaging<25,>=16.8->streamlit) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from pandas<3,>=1.3.0->streamlit) (2022.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (2022.9.24)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.9 MB/s eta 0:00:00a 0:00:01
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 9.3 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (21.4.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: six>=1.5 in /Users/tandi/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Installing collected packages: tenacity, smmap, pygments, pyarrow, protobuf, mdurl, blinker, pydeck, markdown-it-py, gitdb, rich, gitpython, altair, streamlit
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.3.3 requires pyqt5<5.16, which is not installed.
# spyder 5.3.3 requires pyqtwebengine<5.16, which is not installed.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.25.3 which is incompatible.
# tensorboard 2.11.2 requires protobuf<4,>=3.9.2, but you have protobuf 4.25.3 which is incompatible.
# Successfully installed altair-5.3.0 blinker-1.8.2 gitdb-4.0.11 gitpython-3.1.43 markdown-it-py-3.0.0 mdurl-0.1.2 protobuf-4.25.3 pyarrow-16.1.0 pydeck-0.9.1 pygments-2.18.0 rich-13.7.1 smmap-5.0.1 streamlit-1.34.0 tenacity-8.3.0

# %%
import streamlit as st
import pandas as pd
import json

# Placeholder to store events
if 'events' not in st.session_state:
    st.session_state['events'] = []

# Streamlit form
with st.form(key='user_input_form'):
    card_type = st.radio("Card Type:", ['Visa', 'Mastercard', 'Discover', 'JCB'])
    name = st.text_input("Your Name")
    card_number = st.text_input("Your Card Number")
    cvc = st.text_input("CVC")
    expiry = st.text_input("Expiry MM/YY")
    submit_button = st.form_submit_button("Pay Now")

# JavaScript to capture events and send them to Streamlit
js_code = """
<script>
document.addEventListener('DOMContentLoaded', function() {
    const form = document.querySelector('.stForm');
    form.addEventListener('keydown', (event) => {
        // Post keydown event to Streamlit
        const message = {type: 'keydown', key: event.key, time: Date.now()};
        parent.postMessage({type: 'streamlit:setComponentValue', key: 'events', value: JSON.stringify(message)}, '*');
    });

    form.addEventListener('keyup', (event) => {
        // Post keyup event to Streamlit
        const message = {type: 'keyup', key: event.key, time: Date.now()};
        parent.postMessage({type: 'streamlit:setComponentValue', key: 'events', value: JSON.stringify(message)}, '*');
    });

    // Add mouse event listeners if needed
});

// Add a handler for Streamlit events
window.addEventListener("message", (event) => {
    const {type, key, value} = event.data;
    if (type === 'streamlit:formSubmit') {
        // Clear events on form submit
        Streamlit.setComponentValue('events', []);
    }
});
</script>
"""
st.markdown(js_code, unsafe_allow_html=True)

# Handle event logging
event_data = st.text_input("Event log (hidden)", "", key='events', on_change=lambda: st.session_state['events'].append(json.loads(st.session_state['events'])))
st.write("Logged Events:", st.session_state['events'])

# Compute metrics when form is submitted
if submit_button:
    events_df = pd.DataFrame(st.session_state['events'])
    # Process the events_df to compute dwell time, flight time, and trajectory
    # Example: Calculate dwell times
    dwell_times = events_df[events_df['type'] == 'keyup'].time - events_df[events_df['type'] == 'keydown'].time.shift(1)
    st.write("Average Dwell Time:", dwell_times.mean())
    # Reset or clear events after processing
    st.session_state['events'] = []
# Out:
# 2024-05-20 13:38:24.897 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2024-05-20 13:38:24.964
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/tandi/opt/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/session_state.py in __getitem__(self, key)
#     410         try:
# --> 411             return self._getitem(widget_id, key)
#     412         except KeyError:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/session_state.py in _getitem(self, widget_id, user_key)
#     455         # We'll never get here
# --> 456         raise KeyError
#     457
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/y5/9_8d_c414dz7jswv11d4lwtm0000gn/T/ipykernel_28842/1224439598.py in <module>
#      50 # Handle event logging
#      51 event_data = st.text_input("Event log (hidden)", "", key='events', on_change=lambda: st.session_state['events'].append(json.loads(st.session_state['events'])))
# ---> 52 st.write("Logged Events:", st.session_state['events'])
#      53
#      54 # Compute metrics when form is submitted
#
# ~/opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/session_state_proxy.py in __getitem__(self, key)
#      88         key = str(key)
#      89         require_valid_user_key(key)
# ---> 90         return get_session_state()[key]
#      91
#      92     @gather_metrics("session_state.set_item")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/safe_session_state.py in __getitem__(self, key)
#      91         self._yield_callback()
#      92         with self._lock:
# ---> 93             return self._state[key]
#      94
#      95     def __setitem__(self, key: str, value: Any) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/session_state.py in __getitem__(self, key)
#     411             return self._getitem(widget_id, key)
#     412         except KeyError:
# --> 413             raise KeyError(_missing_key_error_message(key))
#     414
#     415     def _getitem(self, widget_id: str | None, user_key: str | None) -> Any:
#
# KeyError: 'st.session_state has no key "events". Did you forget to initialize it? More info: https://docs.streamlit.io/library/advanced-features/session-state#initialization'
